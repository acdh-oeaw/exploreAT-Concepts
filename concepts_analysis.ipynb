# %%
import random
import time
import pickle
import sys
import json
import re
import string
import collections
import codecs
from io import BytesIO

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import mpld3

from sklearn import feature_extraction

import gensim
from gensim import corpora
from gensim.corpora import WikiCorpus
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence

import pyLDAvis
import pyLDAvis.gensim

import nltk
from nltk.corpus import stopwords
from nltk.tag.sequential import ClassifierBasedTagger
#from nltk.stem.wordnet import WordNetLemmatizer
#from nltk.tokenize import word_tokenize

#sudo apt-get install python-dev graphviz libgraphviz-dev pkg-config
#sudo pip install pygraphviz
import pygraphviz 
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout


from IPython.display import display, Image
from IPython.core.interactiveshell import InteractiveShell

pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## 1 - Fragebogen

# %% [markdown]
# #### Reading fragebogen information

# %%
fb_original = pd.read_pickle('./fb_original.pickle')

# %%
fb_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109 entries, 1 to 109
# Data columns (total 5 columns):
# titel             109 non-null object
# number            109 non-null object
# headwords         109 non-null object
# series            109 non-null object
# headwords_list    109 non-null object
# dtypes: object(5)
# memory usage: 5.1+ KB

# %%
fb_original.head(10)
# Out:
#                                                     titel number  \
# nummer
# 1                                  Fragebogen 1: Kopf (1)      1
# 2                        Fragebogen 2: Die Osterwoche (1)      2
# 3                        Fragebogen 3: Die Osterwoche (2)      3
# 4                                  Fragebogen 4: Kopf (2)      4
# 5       Fragebogen 5: Zeit zwischen Ostern und Fronlei...      5
# 6         Fragebogen 6: Menschl. Haar und Bart (= Kopf 3)      6
# 7                              Fragebogen 7: Hochzeit (1)      7
# 8                              Fragebogen 8: Hochzeit (2)      8
# 9                              Fragebogen 9: Hochzeit (3)      9
# 10                            Fragebogen 10: Hochzeit (4)     10
#
#                                     headwords      series  \
# nummer
# 1                                        Kopf         (1)
# 2                              Die Osterwoche         (1)
# 3                              Die Osterwoche         (2)
# 4                                        Kopf         (2)
# 5       Zeit zwischen Ostern und Fronleichnam
# 6                      Menschl. Haar und Bart  (= Kopf 3)
# 7                                    Hochzeit         (1)
# 8                                    Hochzeit         (2)
# 9                                    Hochzeit         (3)
# 10                                   Hochzeit         (4)
#
#                       headwords_list
# nummer
# 1                             [kopf]
# 2                       [osterwoche]
# 3                       [osterwoche]
# 4                             [kopf]
# 5       [fronleichnam, zeit, ostern]
# 6              [haar, bart, menschl]
# 7                         [hochzeit]
# 8                         [hochzeit]
# 9                         [hochzeit]
# 10                        [hochzeit]

# %%
#https://matplotlib.org/2.0.2/api/colors_api.html

G = nx.Graph()

for concept_list in fb_original.headwords_list:
    for concept in concept_list:
        G.add_node(concept, color='white')
        
for questionnaire in fb_original.number:
    G.add_node(questionnaire, color='yellow')
    
for idn in fb_original.index:
    for concept in fb_original.loc[idn, 'headwords_list']:
        G.add_edge(concept, fb_original.loc[idn, 'number'], length = 10)

# %%
#print(G.nodes)
print(G.edges)
# Out:
# [('kopf', '1'), ('kopf', '4'), ('osterwoche', '2'), ('osterwoche', '3'), ('fronleichnam', '5'), ('zeit', '5'), ('zeit', '54'), ('zeit', '68'), ('zeit', '72'), ('ostern', '5'), ('ostern', '72'), ('haar', '6'), ('bart', '6'), ('menschl', '6'), ('hochzeit', '7'), ('hochzeit', '8'), ('hochzeit', '9'), ('hochzeit', '10'), ('hochzeit', '11'), ('nase', '12'), ('ohr', '12'), ('auge', '13'), ('besiedelung', '14'), ('besiedelung', '15'), ('flur', '14'), ('flur', '15'), ('feld', '16'), ('feld', '17'), ('feld', '18'), ('feld', '19'), ('feldbestellung', '16'), ('feldbestellung', '17'), ('feldbestellung', '18'), ('feldbestellung', '19'), ('körper', '20'), ('körper', '21'), ('körper', '22'), ('körper', '23'), ('körperteil', '24'), ('körperteil', '77'), ('körperteil', '78'), ('hautkrankheit', '25'), ('hautkrankheit', '26'), ('hautkrankheit', '27'), ('brotbacken', '28'), ('brotbacken', '29'), ('brotbacken', '30'), ('weißgebäck', '31'), ('gliedmaß', '32'), ('arm', '32'), ('arm', '33'), ('hand', '34'), ('finger', '35'), ('schneiderei', '36'), ('schneiderei', '37'), ('schneiderei', '38'), ('schneiderei', '39'), ('kleidung', '40'), ('kleidung', '41'), ('bewegung', '42'), ('bewegung', '43'), ('bewegung', '44'), ('bewegung', '45'), ('bewegung', '46'), ('bewegung', '47'), ('bewegung', '48'), ('bewegung', '49'), ('bewegung', '50'), ('bewegung', '51'), ('bewegung', '52'), ('farbe', '53'), ('mittsommer', '54'), ('neujahr', '54'), ('neujahr', '72'), ('tod', '55'), ('wunsch', '56'), ('bitte', '56'), ('gruß', '56'), ('dank', '56'), ('jagd', '57'), ('jagd', '58'), ('forstwirtschaft', '59'), ('forstwirtschaft', '60'), ('wald', '59'), ('wald', '60'), ('tier', '61'), ('tier', '62'), ('kinderstube', '63'), ('taufe', '63'), ('kind', '63'), ('milchwirtschaft', '64'), ('rindviehzucht', '64'), ('binderei', '65'), ('maurerhandwerk', '65'), ('weinbau', '66'), ('geburt', '67'), ('wochenbett', '67'), ('schweinezucht', '69'), ('ziege', '70'), ('schafzucht', '70'), ('imkerei', '71'), ('schiffahrt', '73'), ('hund', '74'), ('katze', '74'), ('geflügel', '75'), ('pferd', '76'), ('wiese', '79'), ('heuarbeit', '79'), ('fuhrwerke', '80'), ('fuhrwerke', '81'), ('sprache', '82'), ('sprechen', '82'), ('himmel', '83'), ('witterung', '83'), ('gestirne', '83'), ('schuster', '84'), ('fluren', '85'), ('pflanzenwelt', '85'), ('gartenbau', '86'), ('blutsverwandtschaft', '87'), ('altersstufen', '87'), ('liebe', '88'), ('freundschaft', '88'), ('geselligkeit', '88'), ('kirche', '89'), ('religion', '89'), ('mythologisches', '90'), ('unterricht', '91'), ('schule', '91'), ('bauernhof', '92'), ('bauernhof', '93'), ('wärme', '94'), ('feuer', '94'), ('licht', '95'), ('weiblich', '96'), ('arbeit', '96'), ('essen', '97'), ('trinken', '97'), ('gewicht', '98'), ('maß', '98'), ('waage', '98'), ('eßzeug', '98'), ('getränke', '99'), ('speisen', '99'), ('ernte', '100'), ('anbau', '100'), ('feldfrucht', '100'), ('wachstum', '100'), ('bierbrauerei', '101'), ('verwertung', '102'), ('flachs', '102'), ('hanf', '102'), ('fühlen', '103'), ('sehen', '103'), ('hören', '103'), ('erdoberfläche', '104'), ('verkehr', '105'), ('wasser', '106'), ('gewerbe', '107'), ('gewerbe', '108'), ('gewerbe', '109')]

# %%
#https://stackoverflow.com/questions/48240021/alter-edge-length-and-cluster-spacing-in-networkx-matplotlib-force-graph
#if Win: https://graphviz.gitlab.io/_pages/Download/Download_windows.html
# https://stackoverflow.com/questions/4571067/installing-pygraphviz-on-windows?rq=1
#if Anaconda: conda install graphviz pygraphviz -c alubbock
#pip install --global-option=build_ext --global-option="-IC:\Program Files\<path>\Graphviz2.38\include" --global-option="-LC:\Program Files\Graphviz2.38\lib\release\lib" pygraphviz

plt.figure(figsize=(16,18))

#pos = nx.spring_layout(G)
#pos = graphviz_layout(G)
pos = graphviz_layout(G, prog='twopi', args='')


nx.draw_networkx(G, 
                 pos,
                 #width=5,
                 alpha=0.9,
                 #cmap=plt.get_cmap('viridis'),
                 node_color=nx.get_node_attributes(G,'color').values(), 
                 with_labels=True,
                 font_weight='bold', 
                 #font_color='white',
                 )


plt.show()
# Out:
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# ## 2 - Frage

# %% [markdown]
# #### Reading frage information

# %%
frage = pd.read_pickle('./frage.pickle')

# %%
frage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16738 entries, 0 to 16743
# Data columns (total 7 columns):
# fragebogen_id      16738 non-null int64
# nummer             16738 non-null object
# original_frage     16738 non-null object
# main_theme         16738 non-null object
# question_words     16738 non-null object
# semantic_words     16738 non-null object
# syntactic_words    16738 non-null object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %%
frage.head(10)
# Out:
#    fragebogen_id nummer                                     original_frage  \
# 0              1     A1           Kopf: Kopf, Haupt; auch scherzh./übertr.
# 1              1     A2  Kopf: Kopf/Haupt (in urspr. Bed.) in Vergl./Ra...
# 2              1     A3  Kopf: Kopf/Haupt (übertr.) in Vergl./Ra. (das ...
# 3              1     A4  Kopf: schöner, ebenmäßig gebauter Kopf (Christ...
# 4              1    A4a                Kopf: häßlicher, unebenmäßiger Kopf
# 5              1     A5                      Kopf: großer Kopf; großkopfig
# 6              1    A5a                                   Kopf: Wasserkopf
# 7              1     A6                                 Kopf: kleiner Kopf
# 8              1     A7                       Kopf: oben zugespitzter Kopf
# 9              1     A8                                  Kopf: langer Kopf
#
#   main_theme                                     question_words  \
# 0     [kopf]              [übertragen, haupt, scherzhaft, kopf]
# 1     [kopf]  [zerspringen, ursprünglich, möchten, redensart...
# 2     [kopf]  [übertragen, redensarten, vergleich, verdrehen...
# 3     [kopf]  [tituskopf, schön, gebaut, christuskopf, ebenm...
# 4     [kopf]                       [unebenmäßig, häßlich, kopf]
# 5     [kopf]                           [groß, großkopfig, kopf]
# 6     [kopf]                                 [wasserkopf, kopf]
# 7     [kopf]                                      [klein, kopf]
# 8     [kopf]                           [oben, zugespitzt, kopf]
# 9     [kopf]                                       [lang, kopf]
#
#                                       semantic_words  \
# 0                                      [haupt, kopf]
# 1  [zerspringen, ursprünglich, möchten, stehen, v...
# 2  [vergleich, verdrehen, fein, offen, jemand, ha...
# 3  [tituskopf, schön, gebaut, christuskopf, ebenm...
# 4                       [unebenmäßig, häßlich, kopf]
# 5                           [groß, großkopfig, kopf]
# 6                                 [wasserkopf, kopf]
# 7                                      [klein, kopf]
# 8                           [oben, zugespitzt, kopf]
# 9                                       [lang, kopf]
#
#              syntactic_words
# 0   [übertragen, scherzhaft]
# 1   [redensarten, bedeutung]
# 2  [übertragen, redensarten]
# 3                         []
# 4                         []
# 5                         []
# 6                         []
# 7                         []
# 8                         []
# 9                         []

# %% [markdown]
# #### Examining the common concepts

# %%
concepts = []
for entry in frage.syntactic_words.values:  
    for concept in entry:
        concepts.append(concept)
#concepts = [c for c in concepts if c not in german_stopwords]
fdconcepts = collections.Counter(concepts)
fdconcepts.most_common(200)
# Out:
# [('komposita', 1661),
#  ('redensarten', 1491),
#  ('beispiel', 967),
#  ('bedeutung', 866),
#  ('plural', 697),
#  ('deminutiv', 478),
#  ('femininum', 414),
#  ('ausdrücke', 401),
#  ('adjektiv', 282),
#  ('bezeichnung', 270),
#  ('verba', 263),
#  ('ableitungen', 218),
#  ('synonyme', 198),
#  ('wendungen', 189),
#  ('ab', 183),
#  ('übertragen', 159),
#  ('füg', 110),
#  ('aussprache', 90),
#  ('grundwort', 87),
#  ('ausdruck', 83),
#  ('fügungen', 82),
#  ('volkskundliches', 77),
#  ('substantiva', 74),
#  ('angabe', 73),
#  ('spruch', 69),
#  ('bestimmungswort', 68),
#  ('scherzhaft', 66),
#  ('volkstümlich', 62),
#  ('beschreibung', 54),
#  ('ersatzwörter', 50),
#  ('benennung', 49),
#  ('umschreibungen', 47),
#  ('et', 47),
#  ('benennungen', 34),
#  ('en', 32),
#  ('partizip', 31),
#  ('perfekt', 30),
#  ('singular', 29),
#  ('verb', 12),
#  ('akkusativ', 12),
#  ('dativ', 4),
#  ('konjunktiv', 4)]

# %%
concepts = []
for entry in frage.semantic_words.values:  
    for concept in entry:
        concepts.append(concept)
#concepts = [c for c in concepts if c not in german_stopwords]
fdconcepts = collections.Counter(concepts)
fdconcepts.most_common(500)
# Out:
# [('gewerbe', 609),
#  ('körper', 479),
#  ('besonderer', 380),
#  ('wild', 343),
#  ('feld', 321),
#  ('wer', 298),
#  ('gehen', 289),
#  ('kopf', 274),
#  ('jagd', 261),
#  ('waldbaum', 256),
#  ('ähnlich', 243),
#  ('kommen', 234),
#  ('name', 232),
#  ('schneiderei', 214),
#  ('teil', 204),
#  ('bauer', 204),
#  ('sonstig', 189),
#  ('form', 180),
#  ('auge', 176),
#  ('baum', 173),
#  ('gut', 171),
#  ('eisenbahn', 168),
#  ('holz', 166),
#  ('üblich', 162),
#  ('kind', 160),
#  ('heißen', 155),
#  ('art', 150),
#  ('hautkrankh', 144),
#  ('mensch', 141),
#  ('brot', 141),
#  ('vogel', 141),
#  ('pferd', 138),
#  ('wetter', 135),
#  ('haut', 135),
#  ('geschlecht', 133),
#  ('lassen', 132),
#  ('wagenteil', 128),
#  ('hand', 127),
#  ('geben', 125),
#  ('reden', 124),
#  ('klein', 123),
#  ('gewässer', 123),
#  ('groß', 122),
#  ('sei', 122),
#  ('rind', 120),
#  ('bräuche', 118),
#  ('wann', 117),
#  ('fahren', 114),
#  ('volksglaube', 113),
#  ('stelle', 112),
#  ('dergleichen', 112),
#  ('schiffahrt', 110),
#  ('haar', 107),
#  ('verwendung', 107),
#  ('führen', 104),
#  ('fisch', 104),
#  ('bedeuten', 103),
#  ('wiese', 102),
#  ('tag', 101),
#  ('licht', 98),
#  ('wein', 97),
#  ('fuß', 96),
#  ('schauen', 96),
#  ('säugetiere', 96),
#  ('gerät', 95),
#  ('mühle', 95),
#  ('essen', 94),
#  ('post', 94),
#  ('bauch', 93),
#  ('haus', 92),
#  ('alt', 92),
#  ('wort', 91),
#  ('körperteil', 90),
#  ('frauenkleidg', 90),
#  ('stehen', 89),
#  ('eigenschaft', 89),
#  ('wildtierleben', 89),
#  ('feuer', 88),
#  ('mehlspeisen', 88),
#  ('bierbereitg', 88),
#  ('weinbau', 87),
#  ('verwenden', 85),
#  ('wald', 84),
#  ('schlecht', 84),
#  ('verschieden', 83),
#  ('insekt', 83),
#  ('bart', 82),
#  ('schiffsteil', 82),
#  ('ziehen', 81),
#  ('käseerzeugg', 81),
#  ('nennen', 80),
#  ('brotteig', 80),
#  ('hochzeit', 79),
#  ('waldarbeit', 79),
#  ('zugpferd', 79),
#  ('gespann', 79),
#  ('heuernte', 79),
#  ('heu', 78),
#  ('schwein', 78),
#  ('beziehen', 77),
#  ('milch', 77),
#  ('erster', 76),
#  ('ganz', 76),
#  ('wasser', 76),
#  ('stoß', 75),
#  ('hals', 75),
#  ('bewegung', 75),
#  ('zwei', 74),
#  ('schule', 74),
#  ('bein', 74),
#  ('halten', 73),
#  ('bau', 73),
#  ('tod', 73),
#  ('flachs', 73),
#  ('dreschen', 73),
#  ('tier', 72),
#  ('bier', 72),
#  ('ver', 72),
#  ('gewehr', 72),
#  ('weit', 71),
#  ('geschwür', 70),
#  ('milchwirtsch', 70),
#  ('verwandte', 69),
#  ('etwaig', 69),
#  ('schiff', 69),
#  ('leichenfeier', 69),
#  ('jemand', 68),
#  ('nase', 68),
#  ('schlagen', 68),
#  ('blut', 68),
#  ('brust', 68),
#  ('begräbnis', 68),
#  ('zeit', 67),
#  ('wagen', 67),
#  ('gebrauch', 66),
#  ('ohr', 66),
#  ('faßbinder', 66),
#  ('gehn', 65),
#  ('wohnhaus', 65),
#  ('schneider', 65),
#  ('schulunterricht', 65),
#  ('tragen', 64),
#  ('pflanze', 64),
#  ('allgemein', 64),
#  ('jung', 64),
#  ('düngung', 64),
#  ('vogelwild', 64),
#  ('pfingstbrauch', 63),
#  ('arm', 63),
#  ('hoch', 62),
#  ('rot', 62),
#  ('schwarz', 62),
#  ('schaf', 62),
#  ('hautschwellg', 62),
#  ('laufbewegg', 62),
#  ('heilig', 61),
#  ('lebensalter', 61),
#  ('acker', 61),
#  ('rad', 61),
#  ('person', 60),
#  ('gasthaus', 60),
#  ('unterschied', 60),
#  ('kalt', 60),
#  ('ziege', 60),
#  ('gartenblume', 60),
#  ('hausdach', 60),
#  ('dabei', 59),
#  ('bewegen', 59),
#  ('bienen', 59),
#  ('schön', 58),
#  ('geburt', 58),
#  ('werkzeug', 58),
#  ('kleidung', 58),
#  ('backofen', 58),
#  ('gliedmaß', 58),
#  ('jagdhund', 58),
#  ('hanfarbeit', 58),
#  ('bestimmt', 57),
#  ('schießen', 57),
#  ('nehmen', 57),
#  ('obst', 57),
#  ('künstl', 57),
#  ('geistliche', 56),
#  ('zusammen', 56),
#  ('wunde', 56),
#  ('mauerwerk', 56),
#  ('leicht', 55),
#  ('weiß', 55),
#  ('tun', 55),
#  ('be', 55),
#  ('uhr', 55),
#  ('lang', 54),
#  ('pflügen', 54),
#  ('gruß', 54),
#  ('legen', 53),
#  ('zahn', 53),
#  ('bringen', 53),
#  ('maurerarbeit', 53),
#  ('wohnstube', 53),
#  ('kurz', 52),
#  ('vieh', 52),
#  ('ei', 52),
#  ('trinken', 52),
#  ('hören', 52),
#  ('leben', 52),
#  ('fleisch', 52),
#  ('knochen', 52),
#  ('rinderleben', 52),
#  ('farbe', 51),
#  ('zweiter', 51),
#  ('liebe', 51),
#  ('faßbinden', 51),
#  ('getreideernte', 51),
#  ('stark', 50),
#  ('werkzeuge', 50),
#  ('fallen', 50),
#  ('boden', 50),
#  ('ackerboden', 50),
#  ('gesicht', 49),
#  ('voll', 49),
#  ('hund', 49),
#  ('brechen', 49),
#  ('mundartlich', 49),
#  ('finger', 49),
#  ('verletzg', 49),
#  ('weißgebäck', 49),
#  ('taufe', 49),
#  ('womit', 48),
#  ('bezüglich', 48),
#  ('müssen', 48),
#  ('braut', 48),
#  ('zimmermann', 48),
#  ('anwesen', 48),
#  ('essensbereitg', 48),
#  ('eßgerät', 48),
#  ('einzeln', 47),
#  ('fenster', 47),
#  ('trauung', 47),
#  ('hirsch', 47),
#  ('schlafraum', 47),
#  ('gehbewegg', 47),
#  ('strauch', 47),
#  ('wäschewaschen', 47),
#  ('aberglaube', 46),
#  ('liegen', 46),
#  ('weinkeller', 46),
#  ('bes', 45),
#  ('rücken', 45),
#  ('erg', 45),
#  ('mittel', 44),
#  ('mann', 44),
#  ('ausdrücken', 44),
#  ('tätigkeit', 44),
#  ('grund', 44),
#  ('hose', 44),
#  ('wiesenpflanze', 44),
#  ('geschehen', 43),
#  ('stock', 43),
#  ('frau', 43),
#  ('dick', 43),
#  ('fest', 43),
#  ('setzen', 43),
#  ('geld', 43),
#  ('lange', 42),
#  ('arbeit', 42),
#  ('herstellung', 42),
#  ('schwer', 42),
#  ('hochzeitsfeier', 42),
#  ('küche', 42),
#  ('käse', 42),
#  ('verbindung', 42),
#  ('stein', 42),
#  ('weißgebäcke', 42),
#  ('wasserbewegg', 42),
#  ('wöchnerin', 42),
#  ('lehrmittel', 42),
#  ('vergleich', 41),
#  ('krankheit', 41),
#  ('schlag', 41),
#  ('schneiden', 41),
#  ('sagen', 41),
#  ('hühner', 41),
#  ('wildtier', 41),
#  ('weinstock', 41),
#  ('breit', 40),
#  ('dafür', 40),
#  ('mehrere', 40),
#  ('jahr', 40),
#  ('fronleichnam', 40),
#  ('drehen', 40),
#  ('stecken', 40),
#  ('jahreszeit', 40),
#  ('hof', 40),
#  ('feldarbeit', 40),
#  ('wind', 40),
#  ('forstbetrieb', 40),
#  ('nied', 40),
#  ('fischerei', 40),
#  ('küchengerät', 40),
#  ('zuspeis', 40),
#  ('sollen', 39),
#  ('werfen', 39),
#  ('wörter', 39),
#  ('backen', 39),
#  ('schmetterlinge', 39),
#  ('almwirtsch', 39),
#  ('übersetzg', 39),
#  ('wasserbauten', 39),
#  ('grün', 38),
#  ('zunge', 38),
#  ('vieler', 38),
#  ('schlitten', 38),
#  ('sinn', 38),
#  ('ader', 38),
#  ('kutsche', 38),
#  ('straßenverlauf', 38),
#  ('laufen', 37),
#  ('ehe', 37),
#  ('stall', 37),
#  ('säen', 37),
#  ('heiß', 37),
#  ('verwendungen', 37),
#  ('käfer', 37),
#  ('bienenleben', 37),
#  ('neu', 36),
#  ('gewand', 36),
#  ('tageszeit', 36),
#  ('mist', 36),
#  ('weide', 36),
#  ('getreide', 36),
#  ('hart', 36),
#  ('rock', 36),
#  ('köhlerei', 36),
#  ('baumaterial', 36),
#  ('rindfleischsorte', 36),
#  ('darauf', 35),
#  ('her', 35),
#  ('dürfen', 35),
#  ('springen', 35),
#  ('sau', 35),
#  ('mehl', 35),
#  ('steigen', 35),
#  ('gestein', 35),
#  ('türe', 35),
#  ('teig', 35),
#  ('babysachen', 35),
#  ('zeitadv', 35),
#  ('küchengeschirr', 35),
#  ('trocken', 34),
#  ('zug', 34),
#  ('zaun', 34),
#  ('gelb', 34),
#  ('riech', 34),
#  ('most', 34),
#  ('ziegelbrennerei', 34),
#  ('schafwolle', 34),
#  ('landwirtsch', 34),
#  ('hausputz', 34),
#  ('treiben', 33),
#  ('letzter', 33),
#  ('ernte', 33),
#  ('aussehen', 33),
#  ('spiel', 33),
#  ('straße', 33),
#  ('gottesdienst', 33),
#  ('blau', 33),
#  ('leib', 33),
#  ('ziegel', 33),
#  ('maß', 33),
#  ('rinderzucht', 33),
#  ('gemüse', 33),
#  ('frauenhandarbeit', 33),
#  ('fein', 32),
#  ('bauernregeln', 32),
#  ('spielen', 32),
#  ('sitzen', 32),
#  ('sprechen', 32),
#  ('land', 32),
#  ('fuhrwerk', 32),
#  ('halb', 32),
#  ('greifen', 32),
#  ('bad', 32),
#  ('bewegg', 32),
#  ('faß', 32),
#  ('kleinkind', 32),
#  ('pferdegeschirr', 32),
#  ('sumpfpflanze', 32),
#  ('religion', 32),
#  ('hofbrunnen', 32),
#  ('nieder', 31),
#  ('gebet', 31),
#  ('beziehungsweise', 31),
#  ('bock', 31),
#  ('laden', 31),
#  ('l', 31),
#  ('geschmack', 31),
#  ('waage', 31),
#  ('geflügel', 31),
#  ('rinderkrankh', 31),
#  ('fleischspeise', 31),
#  ('kartoffelbau', 31),
#  ('offen', 30),
#  ('gelten', 30),
#  ('brennen', 30),
#  ('eigentlich', 30),
#  ('schon', 30),
#  ('rede', 30),
#  ('kriegen', 30),
#  ('mädchen', 30),
#  ('berg', 30),
#  ('kuh', 30),
#  ('lautung', 30),
#  ('recht', 30),
#  ('objekt', 30),
#  ('balg', 30),
#  ('fell', 30),
#  ('drücken', 30),
#  ('handhaltg', 30),
#  ('brücke', 30),
#  ('alpenpflanze', 30),
#  ('gespenst', 30),
#  ('getreidepflanze', 30),
#  ('straßenbau', 30),
#  ('woche', 29),
#  ('putz', 29),
#  ('betonung', 29),
#  ('eigen', 29),
#  ('stroh', 29),
#  ('gerade', 29),
#  ('feldbearbeitg', 29),
#  ('gewerblich', 29),
#  ('schuster', 29),
#  ('himmel', 29),
#  ('waldschäden', 29),
#  ('weintraube', 29),
#  ('mutterbrust', 29),
#  ('malzbereitg', 29),
#  ('gang', 28),
#  ('verhalten', 28),
#  ('material', 28),
#  ('bleiben', 28),
#  ('frei', 28),
#  ('mutter', 28),
#  ('wissen', 28),
#  ('bauen', 28),
#  ('raum', 28),
#  ('sonstiges', 28),
#  ('alm', 28),
#  ('kriechtiere', 28),
#  ('rinderfutter', 28),
#  ('buttererzeugg', 28),
#  ('schafhaltg', 28),
#  ('grasmahd', 28),
#  ('waldpflanze', 28),
#  ('speisezutaten', 28),
#  ('woraus', 27),
#  ('haare', 27),
#  ('fleck', 27),
#  ('stück', 27),
#  ('tisch', 27),
#  ('kraut', 27),
#  ('häufigkeit', 27),
#  ('grundbesitz', 27),
#  ('grundgrenze', 27),
#  ('erde', 27),
#  ('eln', 27),
#  ('monat', 27),
#  ('deichsel', 27),
#  ('zeitspanne', 27),
#  ('schweinezucht', 27),
#  ('pilz', 27),
#  ('rübenbau', 27),
#  ('bestehen', 26),
#  ('speisen', 26),
#  ('karsa', 26),
#  ('stellen', 26),
#  ('loch', 26),
#  ('benennen', 26),
#  ('sehen', 26),
#  ('gras', 26),
#  ('treten', 26),
#  ('stube', 26),
#  ('cetera', 26),
#  ('katze', 26),
#  ('knecht', 26),
#  ('naß', 26),
#  ('gott', 26),
#  ('el', 26),
#  ('fasching', 26),
#  ('bodenerhebg', 26),
#  ('daran', 25),
#  ('statt', 25),
#  ('tuch', 25),
#  ('sonne', 25),
#  ('warum', 25),
#  ('schwach', 25),
#  ('ende', 25),
#  ('maschine', 25),
#  ('gänse', 25),
#  ('arbeiter', 25)]

# %% [markdown]
# #### Drawing the Graphs of specific Fragebogen / Frage concepts

# %%
#filtered = frage[frage.fragebogen_id <= 4]

#cfilter = "kopf"
#cfilter = "schwarz"
#cfilter = "suppe"
cfilter = "speise"
filtered = frage[frage.semantic_words.apply(lambda x: cfilter in x)]

# %%
G = nx.Graph()

for concept_list in filtered.semantic_words:
    for concept in concept_list:
        G.add_node(concept, color='white')
        
for questionnaire in filtered.fragebogen_id:
    G.add_node(questionnaire, color='yellow')
    
for idn in filtered.index:
    for concept in filtered.loc[idn, 'semantic_words']:
        G.add_edge(concept, filtered.loc[idn, 'fragebogen_id'], length = 10)

# %%
plt.figure(figsize=(32,32))

#pos = nx.spring_layout(G)
#pos = graphviz_layout(G)
pos = graphviz_layout(G, prog='twopi', args='')


nx.draw_networkx(G, 
                 pos,
                 width=1,
                 alpha=0.9,
                 #cmap=plt.get_cmap('viridis'),
                 node_color=nx.get_node_attributes(G,'color').values(), 
                 with_labels=True,
                 #font_weight='bold', 
                 #font_color='white',
                 )


#plt.show()


plt.savefig('./outputs/{}.png'.format(cfilter), bbox_inches='tight')
# Out:
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# ### Topic Modeling with the concepts

# %% [markdown]
# Preparing Document-Term Matrix
#
# All the text documents combined is known as the corpus. To run any mathematical model on text corpus, it is a good practice to convert it into a matrix representation. LDA model looks for repeating term patterns in the entire DT matrix. Python provides many great libraries for text mining practices, “gensim” is one such clean and beautiful library to handle text data. It is scalable, robust and efficient. Following code shows how to convert a corpus into a document-term matrix.

# %%
all_concepts = []
for entry in frage.semantic_words.values:
    all_concepts.append(entry)
    
# Creating the term dictionary of our courpus, where every unique term is assigned an index. 
dictionary = corpora.Dictionary(all_concepts)
#dictionary.filter_extremes(no_below=1, no_above=0.9)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in all_concepts]

# %% [markdown]
# Running LDA Model
#
# Next step is to create an object for LDA model and train it on Document-Term matrix. The training also requires few parameters as input which are explained in the above section. The gensim module allows both LDA model estimation from a training corpus and inference of topic distribution on new, unseen documents.

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel
num_topics = 8

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=num_topics, id2word = dictionary, passes=50)

# %%
ldamodel.print_topics(num_topics=num_topics, num_words=20)
#ldamodel.show_topics(10)
# Out:
# [(0,
#   '0.017*"eisenbahn" + 0.013*"jagd" + 0.010*"wetter" + 0.008*"reden" + 0.008*"licht" + 0.008*"teil" + 0.007*"schneiderei" + 0.006*"dergleichen" + 0.006*"besonderer" + 0.005*"name" + 0.005*"künstl" + 0.005*"erzeugnis" + 0.005*"bein" + 0.004*"körperteil" + 0.004*"essensbereitg" + 0.004*"gewehr" + 0.004*"stock" + 0.004*"form" + 0.003*"leichenfeier" + 0.003*"wer"'),
#  (1,
#   '0.011*"gerät" + 0.010*"waldbaum" + 0.010*"holz" + 0.008*"post" + 0.007*"hand" + 0.007*"bierbereitg" + 0.006*"flachs" + 0.006*"fahren" + 0.006*"bier" + 0.005*"hanfarbeit" + 0.005*"gartenblume" + 0.005*"obst" + 0.005*"schiff" + 0.004*"milch" + 0.004*"liebe" + 0.004*"schlagen" + 0.004*"milchwirtsch" + 0.004*"arm" + 0.003*"legen" + 0.003*"weit"'),
#  (2,
#   '0.008*"werkzeuge" + 0.008*"kommen" + 0.008*"volksglaube" + 0.007*"form" + 0.007*"schule" + 0.006*"weinbau" + 0.005*"insekt" + 0.005*"bau" + 0.004*"heilig" + 0.004*"ausdrücken" + 0.004*"wald" + 0.004*"sonstig" + 0.004*"führen" + 0.004*"mauerwerk" + 0.004*"käseerzeugg" + 0.004*"kalt" + 0.004*"besonderer" + 0.003*"küchengerät" + 0.003*"name" + 0.003*"waldarbeit"'),
#  (3,
#   '0.026*"körper" + 0.017*"wild" + 0.009*"baum" + 0.008*"brücke" + 0.007*"feuer" + 0.007*"rind" + 0.006*"wein" + 0.006*"klein" + 0.005*"schiffsteil" + 0.005*"mensch" + 0.005*"art" + 0.005*"haar" + 0.005*"schiffahrt" + 0.004*"rad" + 0.004*"pferd" + 0.004*"verschieden" + 0.004*"wagenteil" + 0.004*"groß" + 0.004*"boden" + 0.003*"voll"'),
#  (4,
#   '0.012*"gut" + 0.011*"gewässer" + 0.008*"essen" + 0.008*"wasserbauten" + 0.006*"auge" + 0.006*"gespann" + 0.006*"zugpferd" + 0.006*"gasthaus" + 0.006*"schlecht" + 0.006*"schulunterricht" + 0.005*"lebensalter" + 0.005*"eßgerät" + 0.005*"pferd" + 0.004*"schwarz" + 0.004*"zuspeis" + 0.004*"verwandte" + 0.004*"bienen" + 0.004*"weiß" + 0.004*"straßenverlauf" + 0.003*"schön"'),
#  (5,
#   '0.026*"mühle" + 0.018*"gehen" + 0.008*"geschlecht" + 0.008*"mehlspeisen" + 0.007*"schauen" + 0.006*"fuß" + 0.006*"bauch" + 0.006*"brot" + 0.004*"trinken" + 0.004*"tag" + 0.004*"mühl" + 0.004*"wildtierleben" + 0.004*"faßbinder" + 0.004*"üblich" + 0.004*"wäschewaschen" + 0.004*"zimmermann" + 0.004*"eigenschaft" + 0.003*"hoch" + 0.003*"stein" + 0.003*"werkzeug"'),
#  (6,
#   '0.009*"tätigkeit" + 0.009*"vogel" + 0.008*"kopf" + 0.008*"fisch" + 0.007*"körper" + 0.006*"säugetiere" + 0.006*"hautkrankh" + 0.006*"hausdach" + 0.005*"schwein" + 0.005*"hören" + 0.005*"geistliche" + 0.004*"ziege" + 0.004*"etwaig" + 0.004*"leben" + 0.004*"tod" + 0.004*"schaf" + 0.004*"zwei" + 0.004*"feld" + 0.003*"hund" + 0.003*"waldbaum"'),
#  (7,
#   '0.119*"gewerbe" + 0.007*"kind" + 0.006*"bräuche" + 0.005*"wer" + 0.005*"heißen" + 0.005*"feld" + 0.005*"haus" + 0.005*"dreschen" + 0.005*"wiese" + 0.004*"zunftheiliger" + 0.004*"zunfttag" + 0.004*"geben" + 0.004*"besonderer" + 0.004*"heuernte" + 0.004*"heu" + 0.004*"stelle" + 0.004*"wohnhaus" + 0.003*"wasser" + 0.003*"hals" + 0.003*"brust"')]

# %%
topics_matrix = ldamodel.show_topics(formatted=False, num_words=20)
dic_topics = {num:words for num, words in topics_matrix}
df = pd.DataFrame(dic_topics)
df = df.reindex(sorted(df.columns), axis=1)
df.head(20)
#{num:words for num, words in topics_matrix}
# Out:
#                                0                             1  \
# 0       (eisenbahn, 0.016627366)          (gerät, 0.010660619)
# 1            (jagd, 0.012797808)       (waldbaum, 0.009968761)
# 2          (wetter, 0.010277709)           (holz, 0.009830967)
# 3           (reden, 0.008366572)           (post, 0.008452135)
# 4           (licht, 0.008246397)          (hand, 0.0074669714)
# 5            (teil, 0.007706095)   (bierbereitg, 0.0065122144)
# 6    (schneiderei, 0.0071408483)        (flachs, 0.0063714976)
# 7    (dergleichen, 0.0061620725)         (fahren, 0.006332838)
# 8     (besonderer, 0.0056674145)          (bier, 0.0062092147)
# 9           (name, 0.0049794074)    (hanfarbeit, 0.0052694683)
# 10         (künstl, 0.004906778)   (gartenblume, 0.0047356985)
# 11     (erzeugnis, 0.0047841775)          (obst, 0.0046226303)
# 12          (bein, 0.0046883235)        (schiff, 0.0045714993)
# 13     (körperteil, 0.004423168)         (milch, 0.0042460123)
# 14  (essensbereitg, 0.004132714)         (liebe, 0.0039813784)
# 15        (gewehr, 0.0035316732)      (schlagen, 0.0036554665)
# 16          (stock, 0.003525926)  (milchwirtsch, 0.0036236076)
# 17          (form, 0.0035014446)           (arm, 0.0035783723)
# 18   (leichenfeier, 0.003384916)         (legen, 0.0034338597)
# 19           (wer, 0.0033503533)           (weit, 0.003383062)
#
#                               2                            3  \
# 0      (werkzeuge, 0.008204653)        (körper, 0.026184456)
# 1        (kommen, 0.0080725225)          (wild, 0.016559448)
# 2    (volksglaube, 0.007896599)         (baum, 0.0089130495)
# 3           (form, 0.006588342)        (brücke, 0.008021557)
# 4        (schule, 0.0065380177)         (feuer, 0.007200714)
# 5       (weinbau, 0.0056750616)           (rind, 0.00653585)
# 6         (insekt, 0.004770743)          (wein, 0.006404795)
# 7           (bau, 0.0045225676)        (klein, 0.0055877278)
# 8        (heilig, 0.0042281407)   (schiffsteil, 0.005139608)
# 9     (ausdrücken, 0.004065101)        (mensch, 0.005089391)
# 10         (wald, 0.0040036133)          (art, 0.0048498567)
# 11      (sonstig, 0.0039917137)         (haar, 0.0046846173)
# 12       (führen, 0.0038597884)   (schiffahrt, 0.0045731463)
# 13    (mauerwerk, 0.0036786888)           (rad, 0.004360937)
# 14  (käseerzeugg, 0.0036075448)         (pferd, 0.004258009)
# 15         (kalt, 0.0035882015)  (verschieden, 0.0042489646)
# 16   (besonderer, 0.0035069494)      (wagenteil, 0.00424755)
# 17  (küchengerät, 0.0034905162)         (groß, 0.0037903667)
# 18          (name, 0.003375836)        (boden, 0.0037236302)
# 19   (waldarbeit, 0.0033701085)         (voll, 0.0033316829)
#
#                                   4                              5  \
# 0                (gut, 0.012445905)           (mühle, 0.025631836)
# 1           (gewässer, 0.011104633)            (gehen, 0.01770078)
# 2              (essen, 0.007657355)      (geschlecht, 0.008380196)
# 3      (wasserbauten, 0.0075364946)     (mehlspeisen, 0.007891934)
# 4               (auge, 0.006257259)         (schauen, 0.006591718)
# 5            (gespann, 0.005989368)            (fuß, 0.0064162808)
# 6           (zugpferd, 0.005989368)           (bauch, 0.006112393)
# 7          (gasthaus, 0.0059517585)            (brot, 0.005921829)
# 8           (schlecht, 0.005829819)        (trinken, 0.0041846363)
# 9   (schulunterricht, 0.0056727594)            (tag, 0.0041004037)
# 10      (lebensalter, 0.0052746204)           (mühl, 0.0040054047)
# 11          (eßgerät, 0.0048233843)    (wildtierleben, 0.00400318)
# 12             (pferd, 0.004688551)      (faßbinder, 0.0039342106)
# 13          (schwarz, 0.0041789305)         (üblich, 0.0038835923)
# 14           (zuspeis, 0.004008151)  (wäschewaschen, 0.0037131025)
# 15         (verwandte, 0.003901137)     (zimmermann, 0.0036926253)
# 16            (bienen, 0.003865787)    (eigenschaft, 0.0035004022)
# 17              (weiß, 0.003828065)           (hoch, 0.0034869118)
# 18   (straßenverlauf, 0.0038207984)          (stein, 0.0034500118)
# 19            (schön, 0.0032283762)       (werkzeug, 0.0033970913)
#
#                              6                             7
# 0     (tätigkeit, 0.009105376)         (gewerbe, 0.11949459)
# 1           (vogel, 0.0089909)          (kind, 0.0065906616)
# 2          (kopf, 0.007777272)       (bräuche, 0.0064933654)
# 3        (fisch, 0.0077276514)           (wer, 0.0051903427)
# 4          (körper, 0.0074622)        (heißen, 0.0049827886)
# 5   (säugetiere, 0.0059432904)          (feld, 0.0048813606)
# 6    (hautkrankh, 0.005868774)          (haus, 0.0048336294)
# 7       (hausdach, 0.00566684)        (dreschen, 0.00460689)
# 8       (schwein, 0.005488103)         (wiese, 0.0045484095)
# 9         (hören, 0.004692486)  (zunftheiliger, 0.004332737)
# 10   (geistliche, 0.004671029)       (zunfttag, 0.004332737)
# 11       (ziege, 0.0042271884)          (geben, 0.004219667)
# 12      (etwaig, 0.0041635726)     (besonderer, 0.003938272)
# 13        (leben, 0.004010918)      (heuernte, 0.0037633274)
# 14         (tod, 0.0039842813)           (heu, 0.0037356128)
# 15        (schaf, 0.003803231)        (stelle, 0.0036990668)
# 16        (zwei, 0.0036708112)      (wohnhaus, 0.0035336723)
# 17         (feld, 0.003563035)        (wasser, 0.0034734902)
# 18        (hund, 0.0034998853)          (hals, 0.0034322343)
# 19    (waldbaum, 0.0034591625)         (brust, 0.0030982706)

# %%
pyLDAvis.enable_notebook()
p = pyLDAvis.gensim.prepare(ldamodel, doc_term_matrix, dictionary)
pyLDAvis.save_html(p, './outputs/lda.html')
# Out:
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))

# %% [markdown]
# ### Using Word Embeddings

# %%
import gensim
from gensim import corpora
from gensim.corpora import WikiCorpus
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from gensim.models.word2vec import LineSentence
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.test.utils import datapath, get_tmpfile

# %% [markdown]
# #### [trained model 1](https://devmount.github.io/GermanWordEmbeddings/#download)

# %%
# get trained model, files without a suffix, .bin or .model are treated as binary files
trained_model1 = gensim.models.KeyedVectors.load_word2vec_format('../../nlp/German_Word2vec/german.model', binary=True)
# remove original vectors to free up memory
trained_model1.init_sims(replace=True)
# Out:
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# Different [metrics](http://mkusner.github.io/publications/WMD.pdf)

# %%
print(trained_model1.similarity('kopf', 'blau'))
print(trained_model1.distance('kopf', 'blau'))
# Out:
# 0.4494617
# 0.5505383014678955

# %%
words = ['blau', 'rot', 'kopf', 'Gewerbe']
for word in words:
    print()
    print('word: {}'.format(word))
    for result in trained_model1.most_similar(word, topn=20):
        print(result)
        #print("{}: {:.8f}".format(*result))
# Out:
# word: blau
# ('rot', 0.8281903862953186)
# ('gruen', 0.7959476709365845)
# ('gelb', 0.7838804721832275)
# ('orange', 0.7746740579605103)
# ('grau', 0.7626761198043823)
# ('Blau', 0.7593175172805786)
# ('schwarz', 0.755070149898529)
# ('braun', 0.7448124885559082)
# ('tuerkis', 0.7368776202201843)
# ('rosa', 0.7332463264465332)
# ('lila', 0.7257266640663147)
# ('rot_gelb', 0.7144009470939636)
# ('Hellblau', 0.7142020463943481)
# ('gelb_blau', 0.7131950855255127)
# ('blau_rot', 0.7092214822769165)
# ('dunkelblau', 0.707565188407898)
# ('Gelb_Orange', 0.7064606547355652)
# ('pink', 0.7047414779663086)
# ('weiss_rot', 0.7010555267333984)
# ('rot_blau', 0.6987532377243042)
#
# word: rot
# ('gelb', 0.8350189924240112)
# ('gruen', 0.8290626406669617)
# ('blau', 0.8281903266906738)
# ('schwarz', 0.7826082706451416)
# ('orange', 0.7713059186935425)
# ('grau', 0.7314903736114502)
# ('rot_gelb', 0.7234443426132202)
# ('rote', 0.7225121259689331)
# ('braun', 0.7214125990867615)
# ('lila', 0.7197442650794983)
# ('violett', 0.7078529596328735)
# ('Blau', 0.7019246816635132)
# ('dunkelblau', 0.7017204761505127)
# ('blau_rot', 0.7009779214859009)
# ('dunkelrot', 0.7001214027404785)
# ('Knallrot', 0.699853777885437)
# ('tuerkis', 0.697342574596405)
# ('blaue', 0.6954261660575867)
# ('Rot', 0.6952531933784485)
# ('Orange_Rot', 0.6950715780258179)
#
# word: kopf
# ('sperrangelweit_offen', 0.6236331462860107)
# ('angewurzelt', 0.5934494733810425)
# ('bombenfest', 0.5884377360343933)
# ('hinterm_Tresen', 0.586510181427002)
# ('roten_Lettern', 0.5861994028091431)
# ('Haende_Hosentaschen', 0.5840466022491455)
# ('Praesentierteller', 0.5793420076370239)
# ('gluckst', 0.5776612758636475)
# ('splitterfasernackt', 0.5761294364929199)
# ('wackeligen_Beinen', 0.574927568435669)
# ('sekundenlang', 0.5740936398506165)
# ('Pappschild', 0.5710974931716919)
# ('offenem_Mund', 0.5689034461975098)
# ('schunkelt', 0.5687979459762573)
# ('klitschnass', 0.5667245388031006)
# ('stocksteif', 0.5656452775001526)
# ('mittendrin', 0.5653737783432007)
# ('breitbeinig', 0.5641952157020569)
# ('braun_gebrannte', 0.5627420544624329)
# ('aufgerissenen_Augen', 0.5626803040504456)
#
# word: Gewerbe
# ('Gastronomie', 0.6900135278701782)
# ('Handel_Handwerk', 0.6897969245910645)
# ('Gewerbebetriebe', 0.6814968585968018)
# ('Gewerbetreibende', 0.6737226247787476)
# ('Gewerbe_Industrie', 0.6734519004821777)
# ('Kleingewerbe', 0.6694868206977844)
# ('Handel_Gewerbe', 0.6689370274543762)
# ('Einzelhandel', 0.6672752499580383)
# ('Dienstleistung', 0.6646091938018799)
# ('Dienstleistungsbetriebe', 0.6491075754165649)
# ('produzierendes_Gewerbe', 0.6475104093551636)
# ('gewerbliche', 0.6387714147567749)
# ('Handel_Dienstleistung', 0.6318055391311646)
# ('Handwerk', 0.6311502456665039)
# ('Einzelhandel_Gastronomie', 0.6305773258209229)
# ('Gewerbetreibenden', 0.6305484175682068)
# ('Beherbergungs-', 0.6296176910400391)
# ('Industrie_Gewerbe', 0.6269663572311401)
# ('Gewerbeflaechen', 0.6246213316917419)
# ('Gewerbe-', 0.6240788102149963)

# %%
list_words = ['blau', 'rot', 'feld', 'grün', 'gelb']
print(trained_model1.doesnt_match(list_words))
# Out:
# feld
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/gensim/models/keyedvectors.py:876: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %%
for result in trained_model1.most_similar(positive=['frau', 'blau'], negative=['mann']):
    print(result)
# Out:
# ('rosa', 0.6545881032943726)
# ('orange', 0.6302927732467651)
# ('gruen', 0.619945764541626)
# ('rot', 0.619027316570282)
# ('Glitzer', 0.6155712604522705)
# ('lila', 0.6148803234100342)
# ('grau', 0.6142277717590332)
# ('pink', 0.6076772212982178)
# ('knallrot', 0.6024129390716553)
# ('knallige_Farben', 0.5976543426513672)

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# function draw_words
# ... reduces dimensionality of vectors of given words either with PCA or with t-SNE and draws the words into a diagram
# @param word2vec model     to visualize vectors from
# @param list     words     list of word strings to visualize
# @param bool     pca       use PCA (True) or t-SNE (False) to reduce dimensionality 
# @param bool     alternate use different color and label align for every second word
# @param bool     arrows    use arrows to connect related words (items that are next to each other in list)
# @param float    x1        x axis range (from)
# @param float    x2        x axis range (to)
# @param float    y1        y axis range (from)
# @param float    y2        y axis range (to)
# @param string   title     for diagram

def draw_words(model, words, pca=False, alternate=True, arrows=True, x1=3, x2=3, y1=3, y2=3, title=''):
    # get vectors for given words from model
    vectors = [model[word] for word in words]
    if pca:
        pca = PCA(n_components=2, whiten=True)
        vectors2d = pca.fit(vectors).transform(vectors)
    else:
        tsne = TSNE(n_components=2, random_state=0)
        vectors2d = tsne.fit_transform(vectors)

    # draw image
    plt.figure(figsize=(6,6))
    if pca:
        plt.axis([x1, x2, y1, y2])

    first = True # color alternation to divide given groups
    for point, word in zip(vectors2d , words):
        # plot points
        plt.scatter(point[0], point[1], c='r' if first else 'g')
        # plot word annotations
        plt.annotate(
            word, 
            xy = (point[0], point[1]),
            xytext = (-7, -6) if first else (7, -6),
            textcoords = 'offset points',
            ha = 'right' if first else 'left',
            va = 'bottom',
            size = "x-large"
        )
        first = not first if alternate else first

    # draw arrows
    if arrows:
        for i in range(0, len(words)-1, 2):
            a = vectors2d[i][0] + 0.04
            b = vectors2d[i][1]
            c = vectors2d[i+1][0] - 0.04
            d = vectors2d[i+1][1]
            plt.arrow(a, b, c-a, d-b,
                shape='full',
                lw=0.1,
                edgecolor='#bbbbbb',
                facecolor='#bbbbbb',
                length_includes_head=True,
                head_width=0.08,
                width=0.01
            )

    # draw diagram title
    if title:
        plt.title(title)

    plt.tight_layout()
    plt.show()

# %%
# plot currencies
words = ["Schweiz",
         "Franken",
         "Deutschland",
         "Euro",
         "Grossbritannien",
         "britische_Pfund",
         "Japan",
         "Yen",
         "Russland",
         "Rubel",
         "USA",
         "US-Dollar",
         "Kroatien",
         "Kuna"]

draw_words(trained_model1, words, True, True, True, -3, 3, -2, 2, r'$PCA\ Visualisierung:\ W\ddot{a}hrung$')

# %%
# plot related words to 'house'
matches = trained_model1.most_similar(positive=["Haus"], negative=[], topn=10)
words = [match[0] for match in matches]
draw_words(trained_model1, words, True, False, False, -3, 2, -2, 2, r'$PCA\ Visualisierung:\ Haus$')

# %% [markdown]
# #### [trained model 2](https://deepset.ai/german-word-embeddings)

# %% [raw]
# with open('../../nlp/Deepset_models/w2v/W2V_vectors.txt') as f:
#     text = f.readlines()
#
# with open('../../nlp/Deepset_models/w2v/W2V_vectors2.txt', mode='w') as f:
#     f.write(text[0])
#     for line in text[1:]:
#         line = line.replace(r'\\\\', r'\\')
#         words = line.split()
#         primeira = eval(words[0]).decode('utf-8')
#         words[0] = primeira
#         f.write(' '.join(words))
#         f.write('\n')

# %%
w2v_file = '../../nlp/Deepset_models/w2v/W2V_vectors2.txt'
trained_model2 = KeyedVectors.load_word2vec_format(w2v_file, binary=False, encoding="utf-8")
# Out:
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
trained_model2.vectors.shape
# Out:
# (854776, 300)

# %%
print(trained_model2.similarity('kopf', 'blau'))
print(trained_model2.distance('kopf', 'blau'))
# Out:
# 0.31584507
# 0.6841549277305603

# %%
words = ['blau', 'rot', 'kopf', 'gewerbe']
for word in words:
    print()
    print('word: {}'.format(word))
    for result in trained_model2.most_similar(word, topn=20):
        print(result)
        #print("{}: {:.8f}".format(*result))
# Out:
# word: blau
# ('rot', 0.8878530859947205)
# ('grün', 0.8801577687263489)
# ('gelb', 0.8124666213989258)
# ('schwarz', 0.7995022535324097)
# ('weiß', 0.7513998746871948)
# ('violett', 0.7186183333396912)
# ('dunkelblau', 0.7036298513412476)
# ('farben', 0.6818685531616211)
# ('silbern', 0.6753426194190979)
# ('blauen', 0.6669750213623047)
# ('grau', 0.6544827222824097)
# ('blauer', 0.652576744556427)
# ('gestreift', 0.6439394354820251)
# ('lila', 0.6385097503662109)
# ('dunkelrot', 0.6316858530044556)
# ('hellblau', 0.6249961853027344)
# ('schild', 0.6212359070777893)
# ('beige', 0.6211506724357605)
# ('türkis', 0.61705482006073)
# ('blaue', 0.6129087209701538)
#
# word: rot
# ('blau', 0.8878530263900757)
# ('grün', 0.8219360709190369)
# ('gelb', 0.8039773106575012)
# ('schwarz', 0.7836544513702393)
# ('weiß', 0.7218809127807617)
# ('violett', 0.6870977282524109)
# ('dunkelblau', 0.6600711345672607)
# ('silbern', 0.6583701968193054)
# ('farben', 0.64675372838974)
# ('blauen', 0.642576277256012)
# ('grau', 0.636203408241272)
# ('blauer', 0.6272552013397217)
# ('gestreift', 0.6157442927360535)
# ('dunkelrot', 0.6115838289260864)
# ('gelben', 0.6082634925842285)
# ('roter', 0.5950025320053101)
# ('lila', 0.593278169631958)
# ('schild', 0.5921363830566406)
# ('rötlich', 0.5913013815879822)
# ('beige', 0.5876206159591675)
#
# word: kopf
# ('gesicht', 0.6841191053390503)
# ('stirn', 0.6738893389701843)
# ('bauch', 0.6690548658370972)
# ('schultern', 0.6686977744102478)
# ('beine', 0.6631037592887878)
# ('kopfes', 0.6457687616348267)
# ('hals', 0.6446600556373596)
# ('beinen', 0.6417529582977295)
# ('nacken', 0.6392178535461426)
# ('füße', 0.6378521919250488)
# ('oberkörper', 0.6319692730903625)
# ('augen', 0.6305348873138428)
# ('schwanz', 0.6263673305511475)
# ('mantel', 0.6222622990608215)
# ('hinterkopf', 0.6143167018890381)
# ('nase', 0.6106493473052979)
# ('schädel', 0.6097188591957092)
# ('ohren', 0.6087868809700012)
# ('flügeln', 0.6075053215026855)
# ('füßen', 0.60204017162323)
#
# word: gewerbe
# ('handwerks', 0.7324763536453247)
# ('gewerbes', 0.7319357395172119)
# ('produzierenden', 0.7167571783065796)
# ('forstwirtschaft', 0.7155043482780457)
# ('handwerk', 0.7078234553337097)
# ('baugewerbe', 0.7041393518447876)
# ('gastgewerbe', 0.6892585158348083)
# ('verarbeitenden', 0.6879580020904541)
# ('betriebe', 0.6696550250053406)
# ('textil', 0.6665546298027039)
# ('gewerbebetriebe', 0.6662564873695374)
# ('beschäftigten', 0.6626119613647461)
# ('handel', 0.658673107624054)
# ('industrie', 0.6586136817932129)
# ('arbeitsstätten', 0.657267689704895)
# ('gewerblichen', 0.6571222543716431)
# ('bauwirtschaft', 0.6563290357589722)
# ('gewerbliche', 0.6552896499633789)
# ('textilindustrie', 0.6536247730255127)
# ('gastronomie', 0.6521568298339844)

# %%
list_words = ['blau', 'rot', 'feld', 'grün', 'gelb']
print(trained_model2.doesnt_match(list_words))
# Out:
# feld
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/gensim/models/keyedvectors.py:876: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %%
for result in trained_model2.most_similar(positive=['frau', 'blau'], negative=['mann']):
    print(result)
# Out:
# ('rot', 0.6391851305961609)
# ('grün', 0.6378831267356873)
# ('gelb', 0.6027040481567383)
# ('schwarz', 0.5865936279296875)
# ('lila', 0.5341690182685852)
# ('weiß', 0.5315088629722595)
# ('violett', 0.5308850407600403)
# ('blauen', 0.5186036229133606)
# ('blaue', 0.4993555545806885)
# ('silbern', 0.4934939742088318)

# %% [markdown]
# ### Training our own model

# %%
sentences = []
for sentence in frage.semantic_words.values:
    sentences.append(sentence)

own_model = gensim.models.Word2Vec(sentences, min_count=1)

# %%
words = ['blau', 'rot', 'kopf']
for word in words:
    print()
    print('word: {}'.format(word))
    for result in own_model.wv.most_similar(word, topn=20):
        print(result)
        #print("{}: {:.8f}".format(*result))
# Out:
# word: blau
# ('auge', 0.5781344175338745)
# ('bedeuten', 0.5764802098274231)
# ('gut', 0.572135329246521)
# ('weiß', 0.5588843822479248)
# ('feld', 0.557668924331665)
# ('teil', 0.556101381778717)
# ('besonderer', 0.5523701310157776)
# ('wörter', 0.5505334138870239)
# ('sei', 0.5496429204940796)
# ('name', 0.5491291284561157)
# ('mensch', 0.5476049184799194)
# ('körper', 0.546595573425293)
# ('groß', 0.5455187559127808)
# ('holz', 0.5454165935516357)
# ('hautkrankh', 0.5416470170021057)
# ('kopf', 0.5413594245910645)
# ('gewerbe', 0.5413073897361755)
# ('üblich', 0.5406837463378906)
# ('stecken', 0.5405362248420715)
# ('bauer', 0.5387426018714905)
#
# word: rot
# ('gehen', 0.8389332294464111)
# ('kopf', 0.8373012542724609)
# ('name', 0.8300536870956421)
# ('besonderer', 0.8264274597167969)
# ('heißen', 0.8236342668533325)
# ('gewerbe', 0.823276162147522)
# ('ähnlich', 0.823218047618866)
# ('schneiderei', 0.8227623701095581)
# ('bauer', 0.8227145671844482)
# ('teil', 0.8214108347892761)
# ('gut', 0.8190029859542847)
# ('art', 0.8182533979415894)
# ('wer', 0.8178214430809021)
# ('schiffahrt', 0.8167948722839355)
# ('form', 0.816576361656189)
# ('kommen', 0.8163410425186157)
# ('sei', 0.8163129687309265)
# ('wann', 0.8144978284835815)
# ('geben', 0.8128541111946106)
# ('auge', 0.8119778633117676)
#
# word: kopf
# ('name', 0.9327470064163208)
# ('besonderer', 0.9313238263130188)
# ('ähnlich', 0.9304029941558838)
# ('sonstig', 0.9257462620735168)
# ('heißen', 0.9247862100601196)
# ('gewerbe', 0.9243161678314209)
# ('wer', 0.9235671758651733)
# ('teil', 0.9229280948638916)
# ('schneiderei', 0.9222931265830994)
# ('gut', 0.9179206490516663)
# ('haut', 0.9173758625984192)
# ('kommen', 0.9137448072433472)
# ('form', 0.9130682945251465)
# ('bauer', 0.9104362726211548)
# ('gehen', 0.9094077348709106)
# ('sei', 0.9090772867202759)
# ('groß', 0.90553218126297)
# ('vogel', 0.9049251079559326)
# ('auge', 0.904124915599823)
# ('art', 0.90244460105896)

# %% [markdown]
# #### Expanding a graph with similar words

# %%
#cfilter = "kopf"
#cfilter = "schwarz"
cfilter = "suppe"
#cfilter = "speise"
filtered = frage[frage.semantic_words.apply(lambda x: cfilter in x)]

# %%
G = nx.Graph()

for concept_list in filtered.semantic_words:
    for concept in concept_list:
        G.add_node(concept, color='white')
        for w in own_model.wv.most_similar(concept, topn=5):
            G.add_node(w[0], color='white')
            G.add_edge(concept, w[0], length = 10)        
        
for questionnaire in filtered.fragebogen_id:
    G.add_node(questionnaire, color='yellow')
    
for idn in filtered.index:
    for concept in filtered.loc[idn, 'semantic_words']:
        G.add_edge(concept, filtered.loc[idn, 'fragebogen_id'], length = 10)

# %%
plt.figure(figsize=(32,32))

#pos = nx.spring_layout(G)
#pos = graphviz_layout(G)
pos = graphviz_layout(G, prog='twopi', args='')


nx.draw_networkx(G, 
                 pos,
                 width=1,
                 alpha=0.9,
                 cmap=plt.get_cmap('viridis'),
                 node_color=nx.get_node_attributes(G,'color').values(), 
                 with_labels=True,
                 #font_weight='bold', 
                 #font_color='white',
                 )

#plt.show()

plt.savefig('./outputs/{}_plus_similar.png'.format(cfilter), bbox_inches='tight')
# Out:
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# ### Using [Patern.de](https://www.clips.uantwerpen.be/pages/pattern-de)

# %%
import pattern.de as pde

# %%
print(pde.gender('Katze'))
print(pde.article('Katze', pde.DEFINITE, gender=pde.FEMALE, role=pde.OBJECT))
print(pde.singularize('Katzen'))
print(pde.pluralize('Katze'))
print(pde.conjugate('war', pde.INFINITIVE))
print(pde.conjugate('war', pde.PRESENT, 1, pde.SG, mood=pde.SUBJUNCTIVE))
print(pde.predicative('neugierige')) 
print(pde.attributive('neugierig', gender=pde.FEMALE))
print(pde.attributive('neugierig', gender=pde.FEMALE, role=pde.OBJECT))
print(pde.attributive('neugierig', gender=pde.FEMALE, role=pde.INDIRECT, article="die"))
# Out:
# f
# die
# Katze
# Katzen
# sein
# sei
# neugierig
# neugierige
# neugierige
# neugierigen
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/pattern/text/__init__.py:2127: DeprecationWarning: generator '_read' raised StopIteration
#   for v in _read(self._path):

# %%
s = pde.parse('Die böse Katze liegt auf der Matte.', tagset="STTS")
for sentence in s.split():
    print(sentence)
# Out:
# [['Die', 'ARTDEF', 'O', 'O'], ['böse', 'ADJA', 'O', 'O'], ['Katze', 'NN', 'B-NP', 'O'], ['liegt', 'VVFIN', 'B-PP', 'B-PNP'], ['auf', 'APPR', 'B-NP', 'I-PNP'], ['der', 'ARTDEF', 'O', 'O'], ['Matte', 'NN', 'B-NP', 'O'], ['.', 'S', 'O', 'O']]
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/pattern/text/__init__.py:625: DeprecationWarning: generator '_read' raised StopIteration
#   dict.update(self, (x.split(" ")[:2] for x in _read(self._path) if len(x.split(" ")) > 1))
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/pattern/text/__init__.py:868: DeprecationWarning: generator '_read' raised StopIteration
#   list.extend(self, (x.split() for x in _read(self._path)))

# %%
s = pde.parse('Die böse Katze liegt auf der weichen Matte.')
for sentence in s.split():
    print(sentence)
# Out:
# [['Die', 'DT', 'B-NP', 'O'], ['böse', 'JJ', 'I-NP', 'O'], ['Katze', 'NN', 'I-NP', 'O'], ['liegt', 'VB', 'B-VP', 'O'], ['auf', 'IN', 'B-PP', 'B-PNP'], ['der', 'DT', 'B-NP', 'I-PNP'], ['weichen', 'PRP$', 'I-NP', 'I-PNP'], ['Matte', 'NN', 'I-NP', 'I-PNP'], ['.', '.', 'O', 'O']]

# %% [markdown]
# Dividing the concepts by gramatical classes

# %%
def onlynouns(l):
    nouns = [w for w in l if pde.parse(w).split('/')[1] == 'NN']
    return(nouns)

def onlyverbs(l):
    verbs = [w for w in l if pde.parse(w).split('/')[1] == 'VB']
    return(verbs)

def onlyadject(l):
    adjects = [w for w in l if pde.parse(w).split('/')[1] == 'JJ']
    return(adjects)

# %%
frage_POS = pd.concat([frage.semantic_words.apply(onlynouns),
                       frage.semantic_words.apply(onlyverbs),
                       frage.semantic_words.apply(onlyadject)], axis=1)

frage_POS.columns = ['NN','VB', 'ADJ']
frage_POS.head(30)
# Out:
# /home/rsouza/Documents/envs/python_env/lib/python3.6/site-packages/pattern/text/__init__.py:772: DeprecationWarning: generator '_read' raised StopIteration
#   list.extend(self, (x.split() for x in _read(self._path)))
#                                                    NN  \
# 0                                              [kopf]
# 1                      [zerspringen, vergleich, kopf]
# 2                        [vergleich, verdrehen, kopf]
# 3                     [tituskopf, christuskopf, kopf]
# 4                                              [kopf]
# 5                                              [kopf]
# 6                                  [wasserkopf, kopf]
# 7                                              [kopf]
# 8                                  [zugespitzt, kopf]
# 9                                              [kopf]
# 10                                             [kopf]
# 11                                             [kopf]
# 12                                             [kopf]
# 13                                             [kopf]
# 14                                             [kopf]
# 15   [haar, krausem, mohrenkopf, gesichtsfarbe, kopf]
# 16  [fischkopf, aufgezogen, nase, kindskopf, hasen...
# 17       [laus, nißkopf, behafteen, ungeziefer, kopf]
# 18         [typhus, krankheit, kopfweh, kopfes, kopf]
# 19   [krankheit, grindkopf, krätzen, entstellt, kopf]
# 20                            [beule, auswuchs, kopf]
# 21                           [schädeln, schlag, kopf]
# 22                                             [kopf]
# 23                        [weiberkopf, schädel, kopf]
# 24                         [kopfstück, schädel, kopf]
# 25                                        [totenkopf]
# 26              [totenkopf, wiedereingraben, bräuche]
# 27              [nachbildung, totenkopf, totenkopfes]
# 28                            [aberglaube, totenkopf]
# 29  [platte, kästlein, hirnschale, schädeldecke, k...
#
#                                                    VB                     ADJ
# 0                                                  []                      []
# 1                                   [möchten, stehen]          [ursprünglich]
# 2                                                  []           [fein, offen]
# 3                                                  []      [schön, ebenmäßig]
# 4                                                  []  [unebenmäßig, häßlich]
# 5                                                  []      [groß, großkopfig]
# 6                                                  []                      []
# 7                                                  []                 [klein]
# 8                                                  []                      []
# 9                                                  []                  [lang]
# 10                                                 []           [platt, kurz]
# 11                                                 []                      []
# 12                                                 []                 [breit]
# 13                                                 []              [schmaler]
# 14                                                 []                [schief]
# 15                                                 []                [dunkel]
# 16                                                 []            [fischartig]
# 17                                                 []                      []
# 18                                                 []                      []
# 19                                                 []                      []
# 20                                                 []                      []
# 21                                         [schlagen]                      []
# 22                                                 []                      []
# 23                                                 []               [sonstig]
# 24                                                 []               [sonstig]
# 25                                                 []                      []
# 26  [waschen, beziehen, färben, hinterlegen, einwi...                      []
# 27                                                 []                      []
# 28                                                 []                      []
# 29                                                 []                      []

# %% [markdown]
# ### Using [PyGermanet](https://pypi.org/project/pygermanet/)

# %%
from pygermanet import load_germanet, Synset
from scipy.stats.stats import pearsonr

# %%
from pygermanet import load_germanet
gn = load_germanet()

# %%
#word = 'Suppe'
#word = 'falb'
word = 'Kopf'

lem = gn.lemmatise(word)[0]
print("lemma: ", lem)
print()
print("synsets:", gn.synsets(lem))
print()
for synse in gn.synsets(lem):
    for w in synse.lemmas:
        print(w.orthForm)
print()
syn = gn.synsets(lem)[0]
hype = syn.hypernyms
print("hypernyms: ", hype)
hypo = syn.hyponyms
print("hyponyms: ", hypo)
print()
entails = syn.entails
print('entails: ', entails)
genclass = syn.gn_class
print("generic class: ", genclass)
maxdept = syn.max_depth
print('max depth: ', maxdept)
# Out:
# lemma:  Kopf
#
# synsets: [Synset(Birne.n.1), Synset(Kopf.n.2), Synset(Kopf.n.3), Synset(Kopf.n.4), Synset(Kopf.n.6), Synset(Kopf.n.7), Synset(Kopf.n.8), Synset(Leuchte.n.1)]
#
# Birne
# Schädel
# Kopf
# Haupt
# Rübe
# Kopf
# Kopf
# Anfangsteil
# Kopf
# Kopf
# Kopf
# Haupt
# Kopf
# Kopfstück
# Leuchte
# Kopf
#
# hypernyms:  [Synset(Körperteil.n.1)]
# hyponyms:  [Synset(Menschenkopf.n.1), Synset(Grind.n.3), Synset(Männerkopf.n.1), Synset(Tierkopf.n.1), Synset(Krauskopf.n.1), Synset(Engelskopf.n.1), Synset(Köpfchen.n.1), Synset(Charakterkopf.n.1)]
#
# entails:  []
# generic class:  Koerper
# max depth:  6

# %%
for concept_list in frage.semantic_words[0:8]:
    for concept in concept_list:
        lem = gn.lemmatise(concept)[0]
        print("concept: {}, lemma: {} ".format(concept, lem))
        syn = gn.synsets(lem)
        if not syn:
            syn = gn.synsets(lem.title()) #[0]
        else:
            syn = gn.synsets(lem) #[0]
        print("synsets: ", syn)
        for s in syn:
            print("synset lemmas: ", s.lemmas)
            print()
        hype = syn.hypernyms
        #print("hypernyms: ", hype)
        hypo = syn.hyponyms
        #print("hyponyms: ", hypo)
        entails = syn.entails
        #print('entails: ', entails)
        genclass = syn.gn_class
        print("generic class: ", genclass)
        maxdept = syn.max_depth
        #print('max depth: ', maxdept)
        print()
# Out:
# concept: haupt, lemma: haupt
# synsets:  [Synset(Birne.n.1), Synset(Kopf.n.7)]
# synset lemmas:  [Lemma(Birne.n.1.Birne), Lemma(Birne.n.1.Schädel), Lemma(Birne.n.1.Kopf), Lemma(Birne.n.1.Haupt), Lemma(Birne.n.1.Rübe)]
#
# synset lemmas:  [Lemma(Kopf.n.7.Kopf), Lemma(Kopf.n.7.Haupt)]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-2c32355644da> in <module>
#      12             print("synset lemmas: ", s.lemmas)
#      13             print()
# ---> 14         hype = syn.hypernyms
#      15         #print("hypernyms: ", hype)
#      16         hypo = syn.hyponyms
#
# AttributeError: 'list' object has no attribute 'hypernyms'

# %%
lem = gn.lemmatise('feien')[0]

# %%
syn = gn.synsets('fein')

# %% [markdown]
# ### Using [Spacy](https://spacy.io/)

# %%
import spacy

# %%
# https://spacy.io/models
nlp = spacy.load("de_core_news_sm")
#nlp = spacy.load("de_core_news_md")

# %%
for l in frage.semantic_words.values[0:5]:
    for w in l:
        doc = nlp(w)
        for token in doc:
            print(token.text, 
                  token.lemma_, 
                  token.pos_, 
                  token.tag_, 
                  token.dep_,
                  token.shape_, 
                  token.is_alpha, 
                  token.is_stop)
    print()
# Out:
# haupt haupt ADJ ADJD ROOT xxxx True False
# kopf kopf ADJ ADJD ROOT xxxx True False
#
# zerspringen zerspringen VERB VVINF ROOT xxxx True False
# ursprünglich ursprünglich ADJ ADJD ROOT xxxx True False
# möchten mögen VERB VMFIN ROOT xxxx True False
# stehen stehen VERB VVINF ROOT xxxx True False
# vergleich vergleich ADJ ADJD ROOT xxxx True False
# haupt haupt ADJ ADJD ROOT xxxx True False
# kopf kopf ADJ ADJD ROOT xxxx True False
#
# vergleich vergleich ADJ ADJD ROOT xxxx True False
# verdrehen verdrehen VERB VVINF ROOT xxxx True False
# fein fein ADJ ADJD ROOT xxxx True False
# offen offen ADJ ADJD ROOT xxxx True True
# jemand jemand PRON PIS ROOT xxxx True True
# haupt haupt ADJ ADJD ROOT xxxx True False
# kopf kopf ADJ ADJD ROOT xxxx True False
#
# tituskopf tituskopf ADJ ADJD ROOT xxxx True False
# schön schön ADJ ADJD ROOT xxxx True False
# gebaut bauen VERB VVPP ROOT xxxx True False
# christuskopf christuskopf X XY ROOT xxxx True False
# ebenmäßig ebenmäßig ADJ ADJD ROOT xxxx True False
# kopf kopf ADJ ADJD ROOT xxxx True False
#
# unebenmäßig unebenmäßig ADJ ADJD ROOT xxxx True False
# häßlich häßlich ADJ ADJD ROOT xxxx True False
# kopf kopf ADJ ADJD ROOT xxxx True False

# %% [markdown]
# ### Using [Watson Python API](https://github.com/watson-developer-cloud/python-sdk)

# %% [raw]
# from __future__ import print_function
# import json
# from ibm_watson import NaturalLanguageUnderstandingV1
# from ibm_watson.natural_language_understanding_v1 import Features, EntitiesOptions, KeywordsOptions

# %% [raw]
# apikey = open('./watson_api.key', mode='r').read()
# service = NaturalLanguageUnderstandingV1(version='2018-03-16',
#                                          ## url is optional, and defaults to the URL below. Use the correct URL for your region.
#                                          url='https://gateway.watsonplatform.net/natural-language-understanding/api',
#                                          iam_apikey=apikey)
